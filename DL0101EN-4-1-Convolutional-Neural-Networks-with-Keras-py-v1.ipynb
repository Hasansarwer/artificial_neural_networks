# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0101EN-SkillsNetwork/images/IDSN-logo.png" width="400"> </a>
#
# # Convolutional Neural Networks with Keras
#
# Estimated time needed **30** mins

# %% [markdown]
# In this lab, we will learn how to use the Keras library to build convolutional neural networks. We will also use the popular MNIST dataset and we will compare our results to using a conventional neural network.

# %% [markdown]
# ## Objectives for this Notebook
# * How to use the Keras library to build convolutional neural networks
# * Convolutional neural network with one set of convolutional and pooling layers
# * Convolutional neural network with two sets of convolutional and pooling layers

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1. <a href="#Import-Keras-and-Packages">Import Keras and Packages</a>
# 2. <a href="#Convolutional-Neural-Network-with-One-Set-of-Convolutional-and-Pooling-Layers">Convolutional Neural Network with One Set of Convolutional and Pooling Layers</a>
# 3. <a href="#Convolutional-Neural-Network-with-Two-Sets-of-Convolutional-and-Pooling-Layers">Convolutional Neural Network with Two Sets of Convolutional and Pooling Layers</a>
#
# </font>
# </div>

# %% [markdown]
# ### Install the necessary libraries

# %% [markdown]
# Let's start by installing the keras libraries and the packages that we would need to build a neural network.

# %%
# All Libraries required for this lab are listed below. The libraries need to be installed on Skills Network Labs. 
# If you run this notebook on a different environment, e.g. your desktop, you may want to install these.
# !pip install numpy==2.0.2
# !pip install pandas==2.2.2
# !pip install tensorflow_cpu==2.18.0
# !pip install matplotlib==3.9.2

# %% [markdown]
# #### Suppress the tensorflow warning messages
# We use the following code to  suppress the warning messages due to use of CPU architechture for tensoflow.
# You may want to **comment out** these lines if you are using the GPU architechture

# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %% [markdown]
# ## Import Keras and Packages

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Input
from keras.utils import to_categorical

# %% [markdown]
# When working with convolutional neural networks in particular, we will need additional packages.

# %%
from keras.layers import Conv2D # to add convolutional layers
from keras.layers import MaxPooling2D # to add pooling layers
from keras.layers import Flatten # to flatten data for fully connected layers

# %% [markdown]
# ## Convolutional Neural Network with One Set of Convolutional and Pooling Layers

# %%
# import data
from keras.datasets import mnist

# load data
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# reshape to be [samples][pixels][width][height]
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32')

# %% [markdown]
# Let's normalize the pixel values to be between 0 and 1

# %%
X_train = X_train / 255 # normalize training data
X_test = X_test / 255 # normalize test data

# %% [markdown]
# Next, let's convert the target variable into binary categories

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

num_classes = y_test.shape[1] # number of categories

# %% [markdown]
# Next, let's define a function that creates our model. Let's start with one set of convolutional and pooling layers.

# %%
def convolutional_model():
    
    # create model
    model = Sequential()
    model.add(Input(shape=(28, 28, 1)))
    model.add(Conv2D(16, (5, 5), strides=(1, 1), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    
    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    
    # compile model
    model.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])
    return model

# %% [markdown]
# Finally, let's call the function to create the model, and then let's train it and evaluate it.

# %%
# build the model
model = convolutional_model()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/10
# 300/300 - 30s - 102ms/step - accuracy: 0.9184 - loss: 0.2897 - val_accuracy: 0.9714 - val_loss: 0.1025
# Epoch 2/10
# 300/300 - 28s - 94ms/step - accuracy: 0.9750 - loss: 0.0848 - val_accuracy: 0.9817 - val_loss: 0.0605
# Epoch 3/10
# 300/300 - 28s - 93ms/step - accuracy: 0.9829 - loss: 0.0574 - val_accuracy: 0.9857 - val_loss: 0.0476
# Epoch 4/10
# 300/300 - 39s - 130ms/step - accuracy: 0.9866 - loss: 0.0444 - val_accuracy: 0.9852 - val_loss: 0.0414
# Epoch 5/10
# 300/300 - 25s - 82ms/step - accuracy: 0.9888 - loss: 0.0369 - val_accuracy: 0.9865 - val_loss: 0.0411
# Epoch 6/10
# 300/300 - 26s - 85ms/step - accuracy: 0.9908 - loss: 0.0299 - val_accuracy: 0.9874 - val_loss: 0.0379
# Epoch 7/10
# 300/300 - 25s - 83ms/step - accuracy: 0.9922 - loss: 0.0254 - val_accuracy: 0.9864 - val_loss: 0.0420
# Epoch 8/10
# 300/300 - 25s - 82ms/step - accuracy: 0.9938 - loss: 0.0205 - val_accuracy: 0.9864 - val_loss: 0.0414
# Epoch 9/10
# 300/300 - 39s - 131ms/step - accuracy: 0.9946 - loss: 0.0173 - val_accuracy: 0.9881 - val_loss: 0.0366
# Epoch 10/10
# 300/300 - 42s - 138ms/step - accuracy: 0.9950 - loss: 0.0158 - val_accuracy: 0.9875 - val_loss: 0.0378
# Accuracy: 0.987500011920929
#  Error: 1.2499988079071045

# %% [markdown]
# ------------------------------------------

# %% [markdown]
# ## Convolutional Neural Network with Two Sets of Convolutional and Pooling Layers

# %% [markdown]
# Let's redefine our convolutional model so that it has two convolutional and pooling layers instead of just one layer of each.

# %%
def convolutional_model():
    
    # create model
    model = Sequential()
    model.add(Input(shape=(28, 28, 1)))
    model.add(Conv2D(16, (5, 5), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    
    model.add(Conv2D(8, (2, 2), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    
    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    
    # Compile model
    model.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])
    return model

# %% [markdown]
# Now, let's call the function to create our new convolutional neural network, and then let's train it and evaluate it.

# %%
# build the model
model = convolutional_model()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/10
# 300/300 - 32s - 108ms/step - accuracy: 0.8705 - loss: 0.4575 - val_accuracy: 0.9576 - val_loss: 0.1399
# Epoch 2/10
# 300/300 - 28s - 93ms/step - accuracy: 0.9666 - loss: 0.1126 - val_accuracy: 0.9756 - val_loss: 0.0765
# Epoch 3/10
# 300/300 - 29s - 95ms/step - accuracy: 0.9761 - loss: 0.0802 - val_accuracy: 0.9804 - val_loss: 0.0586
# Epoch 4/10
# 300/300 - 39s - 130ms/step - accuracy: 0.9803 - loss: 0.0643 - val_accuracy: 0.9812 - val_loss: 0.0560
# Epoch 5/10
# 300/300 - 29s - 95ms/step - accuracy: 0.9833 - loss: 0.0554 - val_accuracy: 0.9831 - val_loss: 0.0521
# Epoch 6/10
# 300/300 - 27s - 91ms/step - accuracy: 0.9855 - loss: 0.0470 - val_accuracy: 0.9849 - val_loss: 0.0447
# Epoch 7/10
# 300/300 - 40s - 132ms/step - accuracy: 0.9867 - loss: 0.0424 - val_accuracy: 0.9868 - val_loss: 0.0418
# Epoch 8/10
# 300/300 - 27s - 88ms/step - accuracy: 0.9886 - loss: 0.0377 - val_accuracy: 0.9864 - val_loss: 0.0398
# Epoch 9/10
# 300/300 - 27s - 90ms/step - accuracy: 0.9898 - loss: 0.0336 - val_accuracy: 0.9878 - val_loss: 0.0358
# Epoch 10/10
# 300/300 - 27s - 90ms/step - accuracy: 0.9903 - loss: 0.0308 - val_accuracy: 0.9876 - val_loss: 0.0369
# Accuracy: 0.9876000285148621
#  Error: 1.239997148513794

# %% [markdown]
# <h3>Practice Exercise 1</h3>

# %% [markdown]
# Let's see how batch size affects the time required and accuracy of the model training.
# For this, you can try to change batch_size to 1024 and check it's effect on accuracy

# %%
# Write your answer here

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=1024, verbose=2)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/10
# 59/59 - 26s - 446ms/step - accuracy: 0.9933 - loss: 0.0230 - val_accuracy: 0.9887 - val_loss: 0.0343
# Epoch 2/10
# 59/59 - 25s - 427ms/step - accuracy: 0.9942 - loss: 0.0206 - val_accuracy: 0.9883 - val_loss: 0.0328
# Epoch 3/10
# 59/59 - 25s - 431ms/step - accuracy: 0.9944 - loss: 0.0201 - val_accuracy: 0.9887 - val_loss: 0.0326
# Epoch 4/10
# 59/59 - 25s - 425ms/step - accuracy: 0.9946 - loss: 0.0196 - val_accuracy: 0.9881 - val_loss: 0.0355
# Epoch 5/10
# 59/59 - 25s - 428ms/step - accuracy: 0.9945 - loss: 0.0193 - val_accuracy: 0.9892 - val_loss: 0.0333
# Epoch 6/10
# 59/59 - 25s - 423ms/step - accuracy: 0.9948 - loss: 0.0187 - val_accuracy: 0.9887 - val_loss: 0.0337
# Epoch 7/10
# 59/59 - 24s - 413ms/step - accuracy: 0.9948 - loss: 0.0180 - val_accuracy: 0.9888 - val_loss: 0.0330
# Epoch 8/10
# 59/59 - 24s - 405ms/step - accuracy: 0.9952 - loss: 0.0175 - val_accuracy: 0.9887 - val_loss: 0.0338
# Epoch 9/10
# 59/59 - 41s - 702ms/step - accuracy: 0.9953 - loss: 0.0171 - val_accuracy: 0.9894 - val_loss: 0.0325
# Epoch 10/10
# 59/59 - 41s - 700ms/step - accuracy: 0.9952 - loss: 0.0167 - val_accuracy: 0.9894 - val_loss: 0.0326
# Accuracy: 0.9894000291824341
#  Error: 1.0599970817565918

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- Your answer is below:
# # build the model
# model = convolutional_model()
#
# # fit the model
# model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=1024, verbose=2)
#
# # evaluate the model
# scores = model.evaluate(X_test, y_test, verbose=0)
# print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# -->

# %% [markdown]
# <h3>Practice Exercise 2</h3>

# %% [markdown]
# Now, let's see how number of epochs  affect the time required and accuracy of the model training.
# For this, you can keep the batch_size=1024 and epochs=25 and check it's effect on accuracy

# %%
# Write your answer here

model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=25, batch_size=1024, verbose=2)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/25
# 59/59 - 25s - 420ms/step - accuracy: 0.9954 - loss: 0.0161 - val_accuracy: 0.9888 - val_loss: 0.0346
# Epoch 2/25
# 59/59 - 26s - 440ms/step - accuracy: 0.9957 - loss: 0.0152 - val_accuracy: 0.9887 - val_loss: 0.0339
# Epoch 3/25
# 59/59 - 40s - 679ms/step - accuracy: 0.9956 - loss: 0.0154 - val_accuracy: 0.9888 - val_loss: 0.0331
# Epoch 4/25
# 59/59 - 24s - 404ms/step - accuracy: 0.9958 - loss: 0.0149 - val_accuracy: 0.9892 - val_loss: 0.0333
# Epoch 5/25
# 59/59 - 25s - 420ms/step - accuracy: 0.9961 - loss: 0.0141 - val_accuracy: 0.9887 - val_loss: 0.0345
# Epoch 6/25
# 59/59 - 26s - 443ms/step - accuracy: 0.9960 - loss: 0.0140 - val_accuracy: 0.9894 - val_loss: 0.0323
# Epoch 7/25
# 59/59 - 39s - 665ms/step - accuracy: 0.9965 - loss: 0.0133 - val_accuracy: 0.9894 - val_loss: 0.0346
# Epoch 8/25
# 59/59 - 24s - 414ms/step - accuracy: 0.9963 - loss: 0.0129 - val_accuracy: 0.9892 - val_loss: 0.0333
# Epoch 9/25
# 59/59 - 25s - 421ms/step - accuracy: 0.9965 - loss: 0.0125 - val_accuracy: 0.9884 - val_loss: 0.0366
# Epoch 10/25
# 59/59 - 24s - 415ms/step - accuracy: 0.9969 - loss: 0.0118 - val_accuracy: 0.9892 - val_loss: 0.0344
# Epoch 11/25
# 59/59 - 39s - 669ms/step - accuracy: 0.9967 - loss: 0.0116 - val_accuracy: 0.9888 - val_loss: 0.0354
# Epoch 12/25
# 59/59 - 24s - 405ms/step - accuracy: 0.9970 - loss: 0.0115 - val_accuracy: 0.9887 - val_loss: 0.0345
# Epoch 13/25
# 59/59 - 40s - 677ms/step - accuracy: 0.9973 - loss: 0.0104 - val_accuracy: 0.9891 - val_loss: 0.0345
# Epoch 14/25
# 59/59 - 23s - 396ms/step - accuracy: 0.9973 - loss: 0.0103 - val_accuracy: 0.9891 - val_loss: 0.0353
# Epoch 15/25
# 59/59 - 23s - 389ms/step - accuracy: 0.9973 - loss: 0.0101 - val_accuracy: 0.9893 - val_loss: 0.0343
# Epoch 16/25
# 59/59 - 24s - 409ms/step - accuracy: 0.9974 - loss: 0.0097 - val_accuracy: 0.9892 - val_loss: 0.0370
# Epoch 17/25
# 59/59 - 40s - 678ms/step - accuracy: 0.9974 - loss: 0.0096 - val_accuracy: 0.9887 - val_loss: 0.0355
# Epoch 18/25
# 59/59 - 24s - 409ms/step - accuracy: 0.9978 - loss: 0.0086 - val_accuracy: 0.9891 - val_loss: 0.0356
# Epoch 19/25
# 59/59 - 25s - 420ms/step - accuracy: 0.9979 - loss: 0.0085 - val_accuracy: 0.9893 - val_loss: 0.0364
# Epoch 20/25
# 59/59 - 25s - 415ms/step - accuracy: 0.9978 - loss: 0.0084 - val_accuracy: 0.9885 - val_loss: 0.0352
# Epoch 21/25
# 59/59 - 23s - 386ms/step - accuracy: 0.9979 - loss: 0.0080 - val_accuracy: 0.9874 - val_loss: 0.0412
# Epoch 22/25
# 59/59 - 22s - 380ms/step - accuracy: 0.9981 - loss: 0.0077 - val_accuracy: 0.9885 - val_loss: 0.0375
# Epoch 23/25
# 59/59 - 41s - 689ms/step - accuracy: 0.9981 - loss: 0.0076 - val_accuracy: 0.9881 - val_loss: 0.0403
# Epoch 24/25
# 59/59 - 23s - 394ms/step - accuracy: 0.9981 - loss: 0.0071 - val_accuracy: 0.9879 - val_loss: 0.0440
# Epoch 25/25
# 59/59 - 41s - 694ms/step - accuracy: 0.9983 - loss: 0.0069 - val_accuracy: 0.9892 - val_loss: 0.0372
# Accuracy: 0.9891999959945679
#  Error: 1.080000400543213

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- Your answer is below:
# # build the model
# model = convolutional_model()
#
# # fit the model
# model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=25, batch_size=1024, verbose=2)
#
# # evaluate the model
# scores = model.evaluate(X_test, y_test, verbose=0)
# print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
#
#
#     -->

# %% [markdown]
# ### Thank you for completing this lab!
#
# This notebook was created by [Alex Aklson](https://www.linkedin.com/in/aklson/). I hope you found this lab interesting and educational. Feel free to contact me if you have any questions!

# %% [markdown]
# <!--
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2024-11-20  | 3.0  | Aman  |  Updated the library versions to current |
# | 2020-09-21  | 2.0  | Srishti  |  Migrated Lab to Markdown and added to course repo in GitLab |
#
#
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation. All rights reserved. <h3/>

# %% [markdown]
# ## <h3 align="center"> &#169; IBM Corporation. All rights reserved. <h3/>
